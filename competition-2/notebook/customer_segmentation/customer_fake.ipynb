# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
check_case = ["ADJUST", "ADJUST2", "BANK CHARGES", "C2", "CRUK", "D", "DOT", "M", "PADS", "POST", "SP1002", "TEST001", "TEST002"]

# %%
train_csv = pd.read_csv("/opt/ml/code/input/train.csv")

# %% [markdown]
# # TEST customer

# %%
test001_csv = train_csv[(train_csv.product_id=='TEST001')]

# %%
test002_csv = train_csv[(train_csv.product_id=='TEST002')]

# %%
test001_csv
# Out:
#        order_id product_id              description  quantity  \
# 21447    491725    TEST001  This is a test product.        10
# 21702    491742    TEST001  This is a test product.         5
# 21705    491744    TEST001  This is a test product.         5
# 28492    492718    TEST001  This is a test product.         5
# 31276    493410    TEST001  This is a test product.         5
# 31278    493412    TEST001  This is a test product.         5
# 37892    494450    TEST001  This is a test product.         5
# 44909    495295    TEST001  This is a test product.         5
# 62932    497819    TEST001  This is a test product.         5
# 63021    497843    TEST001  This is a test product.         5
# 116368   504188    TEST001  This is a test product.         5
# 291614  C525272    TEST001  This is a test product.        -1
# 291615  C525273    TEST001  This is a test product.        -1
# 291616  C525274    TEST001  This is a test product.        -1
# ...

# %%
test002_csv
# Out:
#       order_id product_id              description  quantity  \
# 28504   492722    TEST002  This is a test product.         1
#
#                 order_date  price  customer_id         country  total
# 28504  2009-12-18 10:55:00   1.65        12346  United Kingdom   1.65

# %%
adjust_csv = train_csv[(train_csv.product_id=='ADJUST')]

# %%
adjust_csv
# Out:
#        order_id product_id                          description  quantity  \
# 48957    495733     ADJUST  Adjustment by john on 26/01/2010 16         1
# 48958    495735     ADJUST  Adjustment by john on 26/01/2010 16         1
# 48959    495734     ADJUST  Adjustment by john on 26/01/2010 16         1
# 48960   C495737     ADJUST  Adjustment by john on 26/01/2010 16        -1
# 48961    495736     ADJUST  Adjustment by john on 26/01/2010 16         1
# ...         ...        ...                                  ...       ...
# 49056    495801     ADJUST  Adjustment by john on 26/01/2010 17         1
# 49057    495802     ADJUST  Adjustment by john on 26/01/2010 17         1
# 159489  C509473     ADJUST  Adjustment by Peter on 24/05/2010 1        -1
# 159490  C509474     ADJUST  Adjustment by Peter on 24/05/2010 1        -1
# 159491  C509475     ADJUST  Adjustment by Peter on 24/05/2010 1        -1
#
#                  order_date     price  customer_id         country     total
# ...

# %%
sorted(list(set(adjust_csv.customer_id)))
# Out:
# [12346,
#  12382,
#  12404,
#  12454,
#  12466,
#  12471,
#  12497,
#  12555,
#  12570,
#  12600,
#  12606,
#  12647,
#  12696,
#  12706,
#  12709,
#  12745,
#  12748,
#  12792,
#  12826,
#  12846,
#  12858,
#  13054,
#  13136,
#  13327,
#  13468,
#  13664,
#  13776,
#  14079,
#  14156,
#  14285,
#  14358,
#  14380,
#  14413,
#  14653,
#  14911,
#  14912,
#  15266,
#  15357,
#  15383,
#  15702,
#  16047,
#  16154,
#  16168,
#  16291,
#  16422,
#  16575,
#  16840,
#  17050,
#  17130,
#  17364,
#  17672,
#  17867,
#  17940]

# %%
train_csv[(train_csv.customer_id==12346)]
# Out:
#        order_id product_id                          description  quantity  \
# 21447    491725    TEST001              This is a test product.        10
# 21702    491742    TEST001              This is a test product.         5
# 21705    491744    TEST001              This is a test product.         5
# 28492    492718    TEST001              This is a test product.         5
# 28504    492722    TEST002              This is a test product.         1
# 31276    493410    TEST001              This is a test product.         5
# 31278    493412    TEST001              This is a test product.         5
# 37892    494450    TEST001              This is a test product.         5
# 44909    495295    TEST001              This is a test product.         5
# 49055   C495800     ADJUST  Adjustment by john on 26/01/2010 17        -1
# 78388    499763      20682           RED SPOTTY CHILDS UMBRELLA         1
# 78389    499763      20679                EDWARDIAN PARASOL RED         1
# ...

# %%
train_csv[(train_csv.customer_id==12346)]['total'].sum()
# Out:
# -85.37099999999919

# %%
train_csv[(train_csv.customer_id==14103)]
# Out:
#       order_id product_id              description  quantity  \
# 62932   497819    TEST001  This is a test product.         5
#
#                 order_date  price  customer_id         country  total
# 62932  2010-02-12 14:58:00    0.0        14103  United Kingdom    0.0

# %%
train_csv[(train_csv.customer_id==14827)]
# Out:
#       order_id product_id              description  quantity  \
# 63021   497843    TEST001  This is a test product.         5
#
#                 order_date  price  customer_id         country  total
# 63021  2010-02-12 15:47:00    0.0        14827  United Kingdom    0.0

# %%
# 2009에만 구입한 customer는 빼도 괜찮을듯

# %%
train_csv[(train_csv.customer_id==16454)]
# Out:
#        order_id product_id                          description  quantity  \
# 55361   C496598       POST                              POSTAGE        -1
# 112883   503830     46000M         POLYESTER FILLER PAD 45x45cm         1
# 116368   504188    TEST001              This is a test product.         5
# 291614  C525272    TEST001              This is a test product.        -1
# 291615  C525273    TEST001              This is a test product.        -1
# 502533  C549930          M                               Manual        -1
# 676041   569915     90012A  MIDNIGHT BLUE DROP CRYSTAL NECKLACE         2
# 706424   572832          M                               Manual         1
#
#                  order_date    price  customer_id         country    total
# 55361   2010-02-02 16:18:00   8.2500        16454  United Kingdom  -8.2500
# 112883  2010-04-07 15:54:00   2.5575        16454  United Kingdom   2.5575
# 116368  2010-04-12 09:52:00   7.4250        16454  United Kingdom  37.1250
# ...

# %%
train_csv[(train_csv.customer_id==16446)]
# Out:
#        order_id product_id              description  quantity  \
# 291617  C525275    TEST001  This is a test product.        -2
# 531730   553573      22980   PANTRY SCRUBBING BRUSH         1
# 531731   553573      22982      PANTRY PASTRY BRUSH         1
#
#                  order_date   price  customer_id         country    total
# 291617  2010-10-04 16:38:00  7.4250        16446  United Kingdom -14.8500
# 531730  2011-05-18 09:52:00  2.7225        16446  United Kingdom   2.7225
# 531731  2011-05-18 09:52:00  2.0625        16446  United Kingdom   2.0625

# %% [markdown]
# # POST customer

# %%
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

# %%
train_csv[(train_csv.product_id=='POST')]
# Out:
#        order_id product_id description  quantity           order_date  \
# 89       489439       POST     POSTAGE         3  2009-12-01 09:28:00
# 126      489444       POST     POSTAGE         1  2009-12-01 09:55:00
# 173      489447       POST     POSTAGE         1  2009-12-01 10:10:00
# 611      489526       POST     POSTAGE         6  2009-12-01 11:50:00
# 893     C489538       POST     POSTAGE        -1  2009-12-01 12:18:00
# ...         ...        ...         ...       ...                  ...
# 779836   579747       POST     POSTAGE         3  2011-11-30 14:40:00
# 779988   579786       POST     POSTAGE         2  2011-11-30 15:31:00
# 779995   579790       POST     POSTAGE         2  2011-11-30 15:38:00
# 780064   579792       POST     POSTAGE         5  2011-11-30 15:43:00
# 780273   579870       POST     POSTAGE         2  2011-11-30 16:47:00
#
#           price  customer_id         country    total
# 89       29.700        12682          France   89.100
# ...

# %%
unique_post_customer = list(set(train_csv[(train_csv.product_id=='POST')]['customer_id']))

# %%
len(unique_post_customer)
# Out:
# 488
