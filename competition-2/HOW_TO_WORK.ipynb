# %%
# !python inference.py -h
# Out:
# usage: inference.py [-h] param_json
#
# positional arguments:
#   param_json  set path of parameter json file
#
# optional arguments:
#   -h, --help  show this help message and exit

# %%
# !python inference.py /opt/ml/code/src/param_json.json
# Out:
# baseline model:
# 	LightGBM with k-fold cross validation
# seed:
# 	42
# ################################################################################
# data_dir:
# 	/opt/ml/code/input
# output_dir:
# 	/opt/ml/code
# model_params_dir:
# 	/opt/ml/code/src/model_params.json
# period_rule:
# 	period 0:	[day] 7 ~ 0
# 	period 1:	[day] 14 ~ 7
# 	period 2:	[day] 30 ~ 14
# 	period 3:	[month] 2 ~ 1
# 	period 4:	[month] 3 ~ 2
# 	period 5:	[month] 6 ~ 3
# 	period 6:	[month] 6 ~ 0
# 	period 7:	[month] 9 ~ 6
# 	period 8:	[month] 12 ~ 9
# 	period 9:	[month] 15 ~ 12
# 	period 10:	[month] 22 ~ 0
# ################################################################################
# ret_data.shape (455, 162)
# ret_data.shape (386, 162)
# ret_data.shape (732, 162)
# ret_data.shape (980, 162)
# ret_data.shape (993, 162)
# ret_data.shape (2024, 162)
# ret_data.shape (2974, 162)
# ret_data.shape (1812, 162)
# ret_data.shape (2729, 162)
# ret_data.shape (2099, 162)
# ret_data.shape (5501, 162)
# ...
